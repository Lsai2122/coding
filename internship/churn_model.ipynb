# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_absolute_error,accuracy_score
from sklearn.model_selection import train_test_split

# %%
path = "Customer_Churn_Modelling.csv"
data = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 path = "Customer_Churn_Modelling.csv"
# ----> 2 data = pd.read_csv(path)
#
# NameError: name 'pd' is not defined

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data = data.replace("Female",0)
data = data.replace("Male",1)
# Out:
# C:\Users\leela\AppData\Local\Temp\ipykernel_4772\2205713962.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data = data.replace("Male",1)

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France       0   42
# 1             2    15647311       Hill          608     Spain       0   41
# 2             3    15619304       Onio          502    France       0   42
# 3             4    15701354       Boni          699    France       0   39
# 4             5    15737888   Mitchell          850     Spain       0   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France       1   39
# 9996       9997    15569892  Johnstone          516    France       1   35
# 9997       9998    15584532        Liu          709    France       0   36
# 9998       9999    15682355  Sabbatini          772   Germany       1   42
# 9999      10000    15628319     Walker          792    France       0   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
features = ["CreditScore" , "Age","Tenure" ,"Balance" ,"NumOfProducts","HasCrCard","IsActiveMember" ]

# %%
X = data[features]

# %%
y = data.Exited

# %%
ids = data.CustomerId

# %%
df_model = pd.DataFrame(X,y)

# %%
df_model
# Out:
#         CreditScore  Age  Tenure  NumOfProducts  HasCrCard  IsActiveMember
# Exited
# 1               608   41       1              1          0               1
# 0               619   42       2              1          1               1
# 1               608   41       1              1          0               1
# 0               619   42       2              1          1               1
# 0               619   42       2              1          1               1
# ...             ...  ...     ...            ...        ...             ...
# 0               619   42       2              1          1               1
# 0               619   42       2              1          1               1
# 1               608   41       1              1          0               1
# 1               608   41       1              1          0               1
# 0               619   42       2              1          1               1
#
# [10000 rows x 6 columns]

# %%
df_model.corr()
# Out:
#                 CreditScore  Age  Tenure  NumOfProducts  HasCrCard  \
# CreditScore             1.0  1.0     1.0            NaN        1.0
# Age                     1.0  1.0     1.0            NaN        1.0
# Tenure                  1.0  1.0     1.0            NaN        1.0
# NumOfProducts           NaN  NaN     NaN            NaN        NaN
# HasCrCard               1.0  1.0     1.0            NaN        1.0
# IsActiveMember          NaN  NaN     NaN            NaN        NaN
#
#                 IsActiveMember
# CreditScore                NaN
# Age                        NaN
# Tenure                     NaN
# NumOfProducts              NaN
# HasCrCard                  NaN
# IsActiveMember             NaN

# %%
data.dropna(axis=0)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France       0   42
# 1             2    15647311       Hill          608     Spain       0   41
# 2             3    15619304       Onio          502    France       0   42
# 3             4    15701354       Boni          699    France       0   39
# 4             5    15737888   Mitchell          850     Spain       0   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France       1   39
# 9996       9997    15569892  Johnstone          516    France       1   35
# 9997       9998    15584532        Liu          709    France       0   36
# 9998       9999    15682355  Sabbatini          772   Germany       1   42
# 9999      10000    15628319     Walker          792    France       0   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore        Gender           Age  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800      0.545700     38.921800
# std     2886.89568  7.193619e+04     96.653299      0.497932     10.487806
# min        1.00000  1.556570e+07    350.000000      0.000000     18.000000
# 25%     2500.75000  1.562853e+07    584.000000      0.000000     32.000000
# 50%     5000.50000  1.569074e+07    652.000000      1.000000     37.000000
# 75%     7500.25000  1.575323e+07    718.000000      1.000000     44.000000
# max    10000.00000  1.581569e+07    850.000000      1.000000     92.000000
#
#              Tenure        Balance  NumOfProducts    HasCrCard  \
# count  10000.000000   10000.000000   10000.000000  10000.00000
# mean       5.012800   76485.889288       1.530200      0.70550
# std        2.892174   62397.405202       0.581654      0.45584
# ...

# %%
df_model.describe()
# Out:
#         CreditScore           Age        Tenure  NumOfProducts     HasCrCard  \
# count  10000.000000  10000.000000  10000.000000        10000.0  10000.000000
# mean     616.759300     41.796300      1.796300            1.0      0.796300
# std        4.430454      0.402769      0.402769            0.0      0.402769
# min      608.000000     41.000000      1.000000            1.0      0.000000
# 25%      619.000000     42.000000      2.000000            1.0      1.000000
# 50%      619.000000     42.000000      2.000000            1.0      1.000000
# 75%      619.000000     42.000000      2.000000            1.0      1.000000
# max      619.000000     42.000000      2.000000            1.0      1.000000
#
#        IsActiveMember
# count         10000.0
# mean              1.0
# std               0.0
# min               1.0
# 25%               1.0
# 50%               1.0
# 75%               1.0
# max               1.0

# %%
model = DecisionTreeClassifier(random_state=100)

# %%
trainx,valx,trainy,valy=train_test_split(X,y)

# %%
model.fit(trainx,trainy)
# Out:
# DecisionTreeClassifier(random_state=100)

# %%
accuracy_score(model.predict(valx),valy)
# Out:
# 0.7652
